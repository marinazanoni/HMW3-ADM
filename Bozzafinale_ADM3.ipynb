# %% [markdown]
# import libraries

# %%
import pandas as pd
import json
from collections import defaultdict
from bs4 import BeautifulSoup
import requests
import os
import re
from collections import Counter
from functools import reduce
from tqdm.notebook import tqdm
from functools import reduce

# %% [markdown]
# import custom functions

# %%
# Specify the full path to the module (including the filename)
module_path = '/content/drive/MyDrive/HM3-ADM/HW3_ADM/parser.py'

# Import the module using importlib (a workaround if the standard import doesn't work)
import importlib.util
spec = importlib.util.spec_from_file_location("parser", module_path)
parser = importlib.util.module_from_spec(spec)
spec.loader.exec_module(parser)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1 Data collection

# %% [markdown]
# ## 1.1. Get the list of master's degree courses

# %%
def extract_masters(this_url):
    result_url = requests.get(this_url)
    result_soup = BeautifulSoup(result_url.text, 'html.parser')
    result_links = result_soup.find_all('a', {'class': 'courseLink'})
    result_list = []
    for item in result_links:
        result_list.append(item['href'])
    return result_list

# %%
# Output file path
output_file_path = 'msc_urls.txt'
# Loop through the first 400 pages and write results to the output file
with open(output_file_path, 'a') as output_file:
    for page_number in range(1, 401):
        page_url = f'https://www.findamasters.com/masters-degrees/msc-degrees/?PG={page_number}'
        page_results = extract_masters(page_url)
        for url in page_results:
            output_file.write(f'{url}\n')
        time.sleep(1)

# %%
with open(output_file_path, 'r') as file:
    lines = file.readlines()
    number_of_lines = len(lines)

print(f'The file {output_file_path} contains {number_of_lines} rows.')
# Out:
# The file msc_urls.txt contains 6000 rows.

# %% [markdown]
# ## 1.2. Crawl master's degree pages

# %%
# Function to download HTML from a URL with prefix and save it to a file
def download_and_save_html(url, output_path):
    full_url = 'https://www.findamasters.com/' + url
    try:
        response = requests.get(full_url)
        if response.status_code == 200:
            with open(output_path, 'w', encoding='utf-8') as html_file:
                html_file.write(response.text)
        else:
            print(f"Failed to download {full_url}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading {full_url}: {e}")

# Function to create a directory if it doesn't exist
def create_directory(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

# Main directory for downloaded HTML files
main_directory = 'downloaded_pages'
create_directory(main_directory)

# Iterate through the URLs and download the HTML
with open('msc_urls.txt', 'r') as file:
    for index, url in enumerate(file, start=1):
        # Remove whitespaces and newline characters from the URL
        url = url.strip()

        # Generate the directory path for the current page
        page_directory = os.path.join(main_directory, f'page_{(index - 1) // 15 + 1}')
        create_directory(page_directory)

        # Generate the output HTML file path
        output_path = os.path.join(page_directory, f'course_{index}.html')

        # Download the HTML and save it to the file
        download_and_save_html(url, output_path)
        time.sleep(3)

print("Download complete for all pages.")
# Out:
# Download complete for all pages.

# %% [markdown]
# #[1.3] Parse downloaded pages

# %% [markdown]
# At this point, you should have all the HTML documents about the master's degree of interest, and you can start to extract specific information. The list of the information we desire for each course and their format as desiried.

# %% [markdown]
# #Access the stored HTML pages

# %%
# %pip install google-colab-shell
# import the module once
from google_colab_shell import getshell
# Out:
# Collecting google-colab-shell
#   Downloading google-colab-shell-0.2.tar.gz (4.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: google-colab-shell
#   Building wheel for google-colab-shell (setup.py) ... done
#   Created wheel for google-colab-shell: filename=google_colab_shell-0.2-py3-none-any.whl size=4107 sha256=80e086c86d11d45d2f29c9a491589816fae1262d0347b13dc5ea33ecab08cf12
#   Stored in directory: /root/.cache/pip/wheels/f9/36/65/95dd4599be065418a9fe1f482674c8e716ce540f3f484681d2
# Successfully built google-colab-shell
# Installing collected packages: google-colab-shell
# Successfully installed google-colab-shell-0.2

# %% [markdown]
# used command
#
# ---mettere modalità python--
# git clone https://github.com/marinazanoni/nome_provvisorio.git
#
# after accesing the repository

# %%
def parser(html_page):

    # Define your default values here
    default_values = {
    'courseName': None,
    'universityName': None,
    'facultyName': None,
    'isItFullTime': None,
    'description': None,
    'startDate': None,
    'fees': None,
    'modality': None,
    'duration': None,
    'city': None,
    'administration': None,
    'country': None,
    'url': None
}

    # Create a defaultdict with default values
    info = defaultdict(lambda: default_values)

   # Extract the text (HTML)
    with open(html_page, 'r', encoding='utf-8') as file:
        html_content = file.read()
    page_soup = BeautifulSoup(html_content, 'html.parser')

    # COURSE NAME
    page_links = page_soup.find_all('h1', {'class':'text-white course-header__course-title'})
    if page_links:
        first_h1_text = page_links[0].text
        info['courseName'] = str(first_h1_text)
    #else:
        # Handle the case when no 'h1' with 'data-permutive-title' is found
    #    print("No course name found.")
    #courseName = str(first_h1_text)

    # UNIVERSITY NAME
    # Extracting our tag of interest for the Name
    page_links = page_soup.find_all('a', {'class': 'course-header__institution'})
    # Extracting the name of the course as string and print it
    info['universityName'] = str(page_links[0].contents[0])

    # FACULTY NAME
    page_links = page_soup.find_all('a', {'class': 'course-header__department'})
    info['facultyName'] = str(page_links[0].contents[0])

    # FULL TIME
    page_links = page_soup.find_all('a', {'class': 'inheritFont'})
    info['isItFullTime'] = str(page_links[0].contents[0])

    # SHORT DESCRIPTION
    page_links = page_soup.find('div', {'id': 'Snippet'})
    info['description'] = str(page_links.get_text(separator='\n').strip())

    # STARTING DATE
    page_links = page_soup.find('span', {'class': 'key-info__start-date'})
    info['startDate'] = str(page_links.get_text())

    # FEES
    page_links = page_soup.find('a', {'class': 'noWrap inheritFont'})
    page_links = page_soup.find('div', {'class': 'course-sections__fees'})
    if page_links:
        fees_text = page_links.get_text(separator='\n').strip()
        # Remove "Fees" from the text content
        info['fees'] = fees_text.replace('Fees', '').strip()


    # MODALITY
    page_links = page_soup.find('span', {'class': 'key-info__content key-info__qualification py-2 pr-md-3 text-nowrap d-block d-md-inline-block'})
    # Get all elements within the span using find_all
    elementsWithinSpan = page_links.find_all('a')
    info['modality'] = ' '.join([element.text.strip() for element in elementsWithinSpan])

    # DURATION
    page_links = page_soup.find('span', {'class':'key-info__content key-info__duration py-2 pr-md-3 d-block d-md-inline-block'})
    info['duration']=str(page_links.text)

    # CITY
    page_links = page_soup.find('a', {'class':'card-badge text-wrap text-left badge badge-gray-200 p-2 m-1 font-weight-light course-data course-data__city'})
    info['city']=str(page_links.text)

    # ADMINISTRATION
    page_links = page_soup.find('span', {'class':'course-header__online-flag badge bg-white p-2 h6 shadow-sm mr-1'})
    if page_links == None:
        info['administration'] = "On Campus"
    else:
        info['administration']=str(page_links.text)

    # COUNTRY
    page_links = page_soup.find('a', {'class':'card-badge text-wrap text-left badge badge-gray-200 p-2 m-1 font-weight-light course-data course-data__country'})
    info['country']=page_links.text

    #URL
    page_links = page_soup.find('link')
    info['url'] = page_links.get('href')


    return(pd.DataFrame([info]))

# %% [markdown]
# *Searching for a tipical hidden file and delete it in order not to have it when exctracting the information from the folder*

# %%
parser('/content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_1/course_1.html')
# Out:
#                                    courseName                 universityName  \
# 0    3D Design for Virtual Environments - MSc  Glasgow Caledonian University
#
#                                    facultyName isItFullTime  \
# 0  School of Engineering and Built Environment    Full time
#
#                                          description  startDate  \
# 0  3D visualisation and animation play a role in ...  September
#
#                                                 fees modality  \
# 0  Please see the university website for further ...      MSc
#
#            duration     city administration         country  \
# 0  1 year full-time  Glasgow      On Campus  United Kingdom
#
#                                                  url
# 0  https://www.findamasters.com/masters-degrees/c...

# %%
file_path_to_remove = '/content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/.DS_Store'
# Delete the hidden file
os.remove(file_path_to_remove)
print(f"The file {file_path_to_remove} has been deleted.")

# %%
len(parsed_dfs)
# Out:
# 5979

# %% [markdown]
# *Applying the function to our html pages*

# %%
# Specifing the path of the folder
folder_path = '/content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages'

# List all files in the folder
files = os.listdir(folder_path)

parsed_dfs = []

# Iterate through all folders and subfolders using os.walk
for folder_path, _, file_names in os.walk(folder_path):
    # Check if there are files in the current folder
    if file_names:
        # Iterate through each file in the current folder
        for file_name in file_names:
            file_path = os.path.join(folder_path, file_name)

            # Store the information only is the dictionary is not empty (has at list a name course)
            try:
                # Parse the file and append the result to the list
                parsed_df = parser(file_path)
                parsed_dfs.append(parsed_df)
            except Exception as e:
                # Print the file path when an exception occurs
                print(f"Error parsing file: {file_path}")
                # print(f"Error details: {e}")

# Concatenate all DataFrames in the list
concatenated_df = pd.concat(parsed_dfs, ignore_index=True)
# Out:
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_118/course_1765.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_119/course_1772.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_128/course_1910.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_140/course_2086.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_196/course_2929.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_196/course_2931.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_215/course_3213.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_291/course_4357.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_293/course_4395.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_299/course_4484.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_307/course_4593.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_32/course_472.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_35/course_517.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_363/course_5438.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_383/course_5740.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_46/course_679.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_51/course_755.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_60/course_894.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_63/course_936.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_71/course_1053.html
# Error parsing file: /content/drive/MyDrive/HM3-ADM/HW3_ADM/downloaded_pages/page_94/course_1407.html

# %%
concatenated_df['url'][3]
# Out:
# 'https://www.findamasters.com/masters-degrees/course/applied-economics-banking-and-financial-markets-online-msc/?i280d8352c56675'

# %%
# Display the concatenated DataFrame
concatenated_df.head()
# Out:
#                                           courseName  \
# 0           3D Design for Virtual Environments - MSc
# 1                        Air Quality Solutions - MSc
# 2                          Analytical Toxicology MSc
# 3    Applied Computer Science and Artificial Inte...
# 4    Applied Economics (Banking and Financial Mar...
#
#                   universityName  \
# 0  Glasgow Caledonian University
# 1            University of Leeds
# 2          King’s College London
# 3         University of Bradford
# 4             University of Bath
#
#                                      facultyName isItFullTime  \
# 0    School of Engineering and Built Environment    Full time
# 1                Institute for Transport Studies    Full time
# 2            Faculty of Life Sciences & Medicine    Full time
# 3  Faculty of Engineering & Digital Technologies    Full time
# 4                      University of Bath Online    Part time
#
#                                          description           startDate  \
# 0  3D visualisation and animation play a role in ...           September
# 1  Up to 7 million people are estimated to die ev...           September
# 2  The Analytical Toxicology MSc is a unique stud...          See Course
# 3  Computer science is the foundation of many exc...  September, January
# 4  From political uncertainty to finance and recr...  September, January
#
#                                                 fees modality  \
# 0  Please see the university website for further ...      MSc
# 1  UK: £12,500 (Total) \nInternational: £28,750 (...      MSc
# 2  Please see the university website for further ...      MSc
# 3  Please see the university website for further ...      MSc
# 4  Cost per 10 credits £722* (10% alumni discount...      MSc
#
#                                    duration      city administration  \
# 0                          1 year full-time   Glasgow      On Campus
# 1  1 year full time, 2 or 3 years part-time     Leeds      On Campus
# 2                       Full-time: One year    London      On Campus
# 3      1 Year Full Time / 2 Years Part Time  Bradford      On Campus
# 4            2 years and 6 months full time      Bath         Online
#
#           country                                                url
# 0  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 1  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 2  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 3  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 4  United Kingdom  https://www.findamasters.com/masters-degrees/c...

# %%
concatenated_df.shape
# Out:
# (5979, 13)

# %%
print(6000-5979, 'were not valid pages')
# Out:
# 21 were not valid pages

# %%
parsed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   courseName      1 non-null      object
#  1   universityName  1 non-null      object
#  2   facultyName     1 non-null      object
#  3   isItFullTime    1 non-null      object
#  4   description     1 non-null      object
#  5   startDate       1 non-null      object
#  6   fees            1 non-null      object
#  7   modality        1 non-null      object
#  8   duration        1 non-null      object
#  9   city            1 non-null      object
#  10  administration  1 non-null      object
#  11  country         1 non-null      object
#  12  url             1 non-null      object
# dtypes: object(13)
# memory usage: 232.0+ bytes

# %%
# Specify the path where you want to save the .tsv file
tsv_file_path = '/content/drive/MyDrive/HM3-ADM/HW3_ADM/MasterDegrees.tsv'

# Save the DataFrame to a .tsv file
concatenated_df.to_csv(tsv_file_path, sep='\t', index=False)

print(f".tsv file saved at: {tsv_file_path}")
# Out:
# .tsv file saved at: /content/drive/MyDrive/HM3-ADM/HW3_ADM/MasterDegrees.tsv

# %% [markdown]
# ### *saving singularly the information about each master (html page)*

# %%
# Iterate through each DataFrame in the list
for index, parsed_df in enumerate(parsed_dfs):
    # Iterate through each row in the DataFrame
    for row_index, row in parsed_df.iterrows():
        # Replace NaN values with empty strings
        single_row = row.fillna(' ')
        # Specify the path where you want to save the .tsv file for the current row
        tsv_file_path = f'/content/drive/MyDrive/HM3-ADM/HW3_ADM/Courses/course_{index}.tsv'
        # Save the single row DataFrame to a .tsv file
        with open(tsv_file_path, 'w') as file:
            file.write('\t'.join(single_row))
        # Uncomment to see all the tsv files
        #print(f".tsv file for row {index}, row {row_index} saved at: {tsv_file_path}")

# %% [markdown]
# #Preproccessing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from nltk.stem import *

# Download the stopwords dataset if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #[2.0.0]

# %% [markdown]
# Uploading the file created after parsing the information

# %%
df = pd.read_csv('/content/drive/MyDrive/HM3-ADM/HW3_ADM/MasterDegrees.tsv',sep='\t')
df.head()
# Out:
#                                           courseName          universityName  \
# 0                        Air Quality Solutions - MSc     University of Leeds
# 1                          Analytical Toxicology MSc   King’s College London
# 2    Applied Computer Science and Artificial Inte...  University of Bradford
# 3    Applied Economics (Banking and Financial Mar...      University of Bath
# 4                          Applied Linguistics - MSc   University of Glasgow
#
#                                      facultyName isItFullTime  \
# 0                Institute for Transport Studies    Full time
# 1            Faculty of Life Sciences & Medicine    Full time
# 2  Faculty of Engineering & Digital Technologies    Full time
# 3                      University of Bath Online    Part time
# 4                   College of Arts & Humanities    Full time
#
#                                          description           startDate  \
# 0  Up to 7 million people are estimated to die ev...           September
# 1  The Analytical Toxicology MSc is a unique stud...          See Course
# 2  Computer science is the foundation of many exc...  September, January
# 3  From political uncertainty to finance and recr...  September, January
# 4  This Masters focuses on how linguistic researc...           September
#
#                                                 fees modality  \
# 0  UK: £12,500 (Total) \nInternational: £28,750 (...      MSc
# 1  Please see the university website for further ...      MSc
# 2  Please see the university website for further ...      MSc
# 3  Cost per 10 credits £722* (10% alumni discount...      MSc
# 4  Please see the university website for further ...      MSc
#
#                                    duration      city administration  \
# 0  1 year full time, 2 or 3 years part-time     Leeds      On Campus
# 1                       Full-time: One year    London      On Campus
# 2      1 Year Full Time / 2 Years Part Time  Bradford      On Campus
# 3            2 years and 6 months full time      Bath         Online
# 4       1 year full-time; 2 years part-time   Glasgow      On Campus
#
#           country                                                url
# 0  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 1  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 2  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 3  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 4  United Kingdom  https://www.findamasters.com/masters-degrees/c...

# %% [markdown]
# ## Stemming

# %%
# Make a copy of the original DataFrame
processed_df = df.copy()

# stemmer
stemmer = PorterStemmer()

processed_df['description'] = processed_df.description.apply(lambda row: ' '.join([stemmer.stem(word) for word in row.split(' ')]))

# %% [markdown]
# ##Lower, removing punctuation and stepwords

# %%
stop_words = set(stopwords.words('english'))

# Function to remove stopwords and punctuation from a text
def clean(text):
    """
    The following function returns the filtered element for each column of a dataframe.
    Filtering operation consists in removing punctuation and removing stopwords given text with lower case
    """
    words = word_tokenize(str(text))
    # Remove punctuation using NLTK and string.punctuation
    filtered_words = [word for word in words if word not in string.punctuation + "’"]
    # Remove stopwords
    filtered_words = [word for word in filtered_words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Selecting columns
text_columns = processed_df.select_dtypes(include='object').columns
# Lower
processed_df[text_columns] = processed_df[text_columns].apply(lambda x: x.str.lower() if x.dtype == 'O' else x)
# Applying clean function to all the valid columns
processed_df[text_columns] = processed_df[text_columns].applymap(clean)

# %%
processed_df.head()
# Out:
#                                           courseName       universityName  \
# 0                          air quality solutions msc     university leeds
# 1                          analytical toxicology msc  king college london
# 2  applied computer science artificial intelligen...  university bradford
# 3  applied economics banking financial markets on...      university bath
# 4                            applied linguistics msc   university glasgow
#
#                                 facultyName isItFullTime  \
# 0               institute transport studies    full time
# 1            faculty life sciences medicine    full time
# 2  faculty engineering digital technologies    full time
# 3                    university bath online    part time
# 4                   college arts humanities    full time
#
#                                          description          startDate  \
# 0  [7, million, peopl, estim, die, everi, year, d...          september
# 1  [analyt, toxicolog, msc, uniqu, studi, cours, ...         see course
# 2  [comput, scienc, foundat, mani, excit, cutting...  september january
# 3  [polit, uncertainti, financ, recruit, demands,...  september january
# 4  [thi, master, focus, linguist, research, help,...          september
#
#                                                 fees modality  \
# 0       uk £12,500 total international £28,750 total      msc
# 1  please see university website information fees...      msc
# 2  please see university website information fees...      msc
# 3  cost per 10 credits £722 10 alumni discount pa...      msc
# 4  please see university website information fees...      msc
#
#                                duration      city administration  \
# 0  1 year full time 2 3 years part-time     leeds         campus
# 1                    full-time one year    london         campus
# 2    1 year full time 2 years part time  bradford         campus
# 3            2 years 6 months full time      bath         online
# 4    1 year full-time 2 years part-time   glasgow         campus
#
#           country                                                url
# 0  united kingdom  https //www.findamasters.com/masters-degrees/c...
# 1  united kingdom  https //www.findamasters.com/masters-degrees/c...
# 2  united kingdom  https //www.findamasters.com/masters-degrees/c...
# 3  united kingdom  https //www.findamasters.com/masters-degrees/c...
# 4  united kingdom  https //www.findamasters.com/masters-degrees/c...

# %% [markdown]
# #[2.0.1]

# %% [markdown]
#  ## we want the field fees to collect numeric information

# %% [markdown]
# We consider only *fees* column and deepen what we find

# %%
raw_fees= pd.DataFrame(processed_df['fees'])

# %%
raw_fees.head()
# Out:
#                                                 fees
# 0  please see university website information fees...
# 1       uk £12,500 total international £28,750 total
# 2  please see university website information fees...
# 3  please see university website information fees...
# 4  cost per 10 credits £722 10 alumni discount pa...

# %% [markdown]
# there are lot of missings data or more complex information we need to filter. To filter we follow the given guidline:
#
#
# > in case of multiple information, retrieve only the highest fees

# %%
pattern = r' (?P<symbol>[^\d\s])(?P<value>\d{1,3}(?:,\d{3})*(?:\.\d{2})?)'

def return_cost(stri):
    """
    this function returns a string built up by the currency and
    the maximum number it appears in the string given in input
    """
    # Search for the patterns in the string (currency, values)
    match = re.findall(pattern, stri)

    if not match:
        return None

    # Store all values
    v = [value for currency, value in match]
    # Extract the maximum
    max_v = max(v)
    # Merge the currency with the value
    merged_list = f'{match[0][0]}{max_v}'
    return merged_list


text_columns = processed_df.select_dtypes(include='object').columns
# Return the list of currency symbols and costs encountered in 'fees' field
raw_fees['fees'] = raw_fees['fees'].apply(lambda x: return_cost(x) if x is not None else None)

# %% [markdown]
# ###here we have filter fees column with only one cost each row, where available

# %%
raw_fees.head()
# Out:
#       fees
# 0     None
# 1  £28,750
# 2     None
# 3     None
# 4     £722

# %%
# Your ExchangeRate-API key
api_key = '40f223580924eaf7a1eb4ee0'

# Fetch exchange rates from the API for all currencies against USD
api_url = f'https://open.er-api.com/v6/latest/USD?apikey={api_key}'
response = requests.get(api_url)
data = response.json()
exchange_rates = data['rates']

# Define a mapping between currency symbols in your data and API symbols
currency_symbol_mapping = {
    '£': 'GBP',
    '€': 'EUR',
    '$': 'USD',
    '¥': 'JPY'
    # Add more currency symbols as needed
}

# Function to convert any currency to the common currency (USD in this case)
def convert_to_common_currency(row, target_currency='USD'):
    if pd.isna(row['fees']):
        return None
    try:
        # Extract the currency symbol from the string
        currency_symbol = row['fees'][0]

        # Map the currency symbol to the API symbol
        api_currency_symbol = currency_symbol_mapping.get(currency_symbol)

        if not api_currency_symbol:
            return None

        # Extract the exchange rate from the pre-fetched rates
        exchange_rate = exchange_rates[api_currency_symbol]

        # Remove the currency symbol and commas, then convert to float
        amount = float(row['fees'][1:].replace(',', ''))

        # Convert to USD using the obtained exchange rate
        amount_target_currency = amount/(exchange_rate)
        return round(amount_target_currency,2)

    except Exception as e:
       return None

# %%
# Apply the conversion function to the 'fees' column
raw_fees['fees'] = raw_fees.apply(convert_to_common_currency, axis=1)

# Rename the column to indicate the common currency
common_currency_code = 'USD'
raw_fees.rename(columns={'fees': f'fees ({common_currency_code})'}, inplace=True)

# %%
raw_fees.head()
# Out:
#    fees (USD)
# 0    35778.51
# 1         NaN
# 2         NaN
# 3      898.51
# 4         NaN

# %% [markdown]
# sustituing and renaming the new column with the appropriate currance values

# %%
processed_df['fees']= raw_fees['fees (USD)']
processed_df.rename(columns={'fees': 'fees (USD)'}, inplace=True)

# %%
processed_df.head()
# Out:
#                                           courseName       universityName  \
# 0                          air quality solutions msc     university leeds
# 1                          analytical toxicology msc  king college london
# 2  applied computer science artificial intelligen...  university bradford
# 3  applied economics banking financial markets on...      university bath
# 4                            applied linguistics msc   university glasgow
#
#                                 facultyName isItFullTime  \
# 0               institute transport studies    full time
# 1            faculty life sciences medicine    full time
# 2  faculty engineering digital technologies    full time
# 3                    university bath online    part time
# 4                   college arts humanities    full time
#
#                                          description          startDate  \
# 0  7 million peopl estim die everi year due harm ...          september
# 1  analyt toxicolog msc uniqu studi cours integr ...         see course
# 2  comput scienc foundat mani excit cutting-edg t...  september january
# 3  polit uncertainti financ recruit demands econo...  september january
# 4  thi master focus linguist research help solv l...          september
#
#    fees (USD) modality                              duration      city  \
# 0    35778.51      msc  1 year full time 2 3 years part-time     leeds
# 1         NaN      msc                    full-time one year    london
# 2         NaN      msc    1 year full time 2 years part time  bradford
# 3      898.51      msc            2 years 6 months full time      bath
# 4         NaN      msc    1 year full-time 2 years part-time   glasgow
#
#   administration         country  \
# 0         campus  united kingdom
# 1         campus  united kingdom
# 2         campus  united kingdom
# 3         online  united kingdom
# 4         campus  united kingdom
#
#                                                  url
# 0  https //www.findamasters.com/masters-degrees/c...
# 1  https //www.findamasters.com/masters-degrees/c...
# 2  https //www.findamasters.com/masters-degrees/c...
# 3  https //www.findamasters.com/masters-degrees/c...
# 4  https //www.findamasters.com/masters-degrees/c...

# %% [markdown]
# #[2.1.1]

# %%
vocabulary = set()

# %%
processed_df['description']= processed_df.description.apply(lambda row: word_tokenize(row))
# Out:
# 0    [7, million, peopl, estim, die, everi, year, d...
# 1    [analyt, toxicolog, msc, uniqu, studi, cours, ...
# 2    [comput, scienc, foundat, mani, excit, cutting...
# 3    [polit, uncertainti, financ, recruit, demands,...
# 4    [thi, master, focus, linguist, research, help,...
# Name: description, dtype: object

# %%
processed_df.description.head()
# Out:
# 0    [7, million, peopl, estim, die, everi, year, d...
# 1    [analyt, toxicolog, msc, uniqu, studi, cours, ...
# 2    [comput, scienc, foundat, mani, excit, cutting...
# 3    [polit, uncertainti, financ, recruit, demands,...
# 4    [thi, master, focus, linguist, research, help,...
# Name: description, dtype: object

# %%
processed_df.description.apply(lambda row: [vocabulary.add(word) for word in row])
# Out:
# 0       [None, None, None, None, None, None, None, Non...
# 1       [None, None, None, None, None, None, None, Non...
# 2       [None, None, None, None, None, None, None, Non...
# 3       [None, None, None, None, None, None, None, Non...
# 4       [None, None, None, None, None, None, None, Non...
#                               ...
# 5974    [None, None, None, None, None, None, None, Non...
# 5975    [None, None, None, None, None, None, None, Non...
# 5976    [None, None, None, None, None, None, None, Non...
# 5977    [None, None, None, None, None, None, None, Non...
# 5978    [None, None, None, None, None, None, None, Non...
# Name: description, Length: 5979, dtype: object

# %%
print('peopl' in vocabulary)
# Out:
# True

# %%
vocabulary
# Out:
# {'status',
#  'strategical',
#  'multi-million',
#  'mdp',
#  'registration',
#  'graduates/gradu',
#  'oral',
#  'supramolecular',
#  'embedded',
#  'transnational',
#  'université',
#  'root',
#  'jump-start',
#  'inact',
#  'football',
#  'launching',
#  'earth',
#  'constitution',
#  'online-preparatori',
#  'governmental',
#  'people-orient',
#  'defense',
#  'medieval',
#  'must',
#  'linguistics',
#  'realiz',
#  'urbanist',
#  '1-year',
#  'especially',
#  'instructions',
#  'phonology',
#  'compel',
#  'view',
#  'microm',
#  'eat',
#  'digital-bas',
#  'diseas',
#  'dangers',
#  'lak',
#  'engagingly',
#  'tomorrow',
#  'ngo/charit',
#  'adversity',
#  'strive',
#  'weight',
#  'extra-curricular',
#  'rates',
#  'demography',
#  'assist',
#  'roy',
#  'geriatr',
#  'biomechanical',
#  'rpl',
#  'qualify',
#  'arithmet',
#  'effici',
#  'realis',
#  'not-for-profit',
#  'manhattan',
#  'accru',
#  'distinct',
#  'startup',
#  'norms',
#  'watt',
#  'well-suit',
#  'wertschöpfung',
#  'webchats',
#  'pocket',
#  'domin',
#  'clinical/psychotherapi',
#  'intak',
#  'vulner',
#  'guarante',
#  'goddard',
#  'offer',
#  'matter-mov',
#  'abil',
#  'occurr',
#  'anna',
#  'concepts',
#  'googl',
#  'coastlines',
#  'floor',
#  'environment',
#  'highest',
#  'summari',
#  'prevent',
#  'ful',
#  'taxi',
#  'relentless',
#  'terrena',
#  'resources-rel',
#  'studios',
#  'virtu',
#  'non-rel',
#  'kingston',
#  'dive',
#  "ip'-",
#  'overexploitation',
#  'advising',
#  'stroke',
#  'phys',
#  'farming',
#  'geohazards',
#  'dedic',
#  'strongli',
#  'imagine',
#  'legalities',
#  'dens',
#  'grad',
#  'superior',
#  'spark',
#  'ghana',
#  'burgo',
#  'fudan',
#  'james',
#  'appropriate',
#  'diabetes',
#  'instmc',
#  'christianity',
#  's-level',
#  'bi',
#  'explicitli',
#  'it-system',
#  'overal',
#  'b-track',
#  'foodborn',
#  'hypnotherapy',
#  'apprenticeship.\u200c',
#  'knowledge',
#  'practitioner-focus',
#  'specified',
#  'major',
#  'industries',
#  'sars-cov-2',
#  'archiv',
#  'iet-accredit',
#  'commercialis',
#  'demographics',
#  'two-day',
#  'm.s.ahd',
#  '7',
#  'gaming',
#  'laws',
#  'well-train',
#  'nanoscal',
#  'interviewing',
#  'working',
#  'acquire',
#  'membership',
#  'concerns',
#  'infer',
#  'digitialis',
#  'competition',
#  'rural',
#  'everard',
#  'upper',
#  'skill-bas',
#  'imaginatively',
#  "master's-level",
#  'le',
#  'general',
#  'biomedicin',
#  'investigative',
#  'incept',
#  'lul',
#  'all-rounder',
#  'interns',
#  'secondari',
#  'century',
#  'undergon',
#  'pinpoint',
#  'hdruk',
#  'inter-languag',
#  'standalon',
#  'endodont',
#  'nature',
#  'love',
#  'cross-cutting',
#  'forward-thinking',
#  'ventilation',
#  'aptitud',
#  'ads',
#  'setup',
#  'zeva',
#  'happening',
#  'policymaking',
#  'bio-bas',
#  'qualifi',
#  'safeguarding',
#  'argument',
#  'apis',
#  'correct',
#  'clients',
#  'durham',
#  'divinity',
#  'enquiri',
#  'experienc',
#  'directli',
#  'mortal',
#  'torino',
#  'astronomi',
#  'interconnected',
#  'tightli',
#  'producers',
#  'emml',
#  'app',
#  'computing-rel',
#  'co-design',
#  'understandings',
#  'nudge',
#  'post-crisi',
#  'ever',
#  'institute®',
#  'locat',
#  'challenging',
#  'involv',
#  'managers/lead',
#  'currenc',
#  'buyer',
#  'psychotherapi',
#  'imat',
#  '16,000',
#  'alga',
#  'criminological',
#  'concurr',
#  'founder',
#  'canterburi',
#  'candidate',
#  'hawaii',
#  'performance',
#  'cultures',
#  'biobas',
#  'portfolios',
#  'sampl',
#  'aspects',
#  '552',
#  'gathered',
#  'cardiorespiratory',
#  '2028',
#  'deglutition',
#  'round',
#  'predefin',
#  'capabilities',
#  'beliefs',
#  'cases',
#  'neurodegen',
#  'thoroughness',
#  'bespok',
#  'blocks',
#  'industry-readi',
#  'orientated',
#  'inventor',
#  'regulatory',
#  'harp',
#  'shadow',
#  'cih',
#  '-primari',
#  'pairings',
#  'lo',
#  'algorithm',
#  'geographies',
#  'webpage',
#  'possible',
#  'wards',
#  'gmnr',
#  'mhs',
#  'marmot',
#  'physical',
#  'hefce',
#  'spp',
#  'n/lab',
#  'environ',
#  'zooarchaeolog',
#  'main',
#  'revisit',
#  'prescriber',
#  'contribut',
#  'recognition',
#  'lifeway',
#  'volum',
#  'ecosystem',
#  'true',
#  'buzz',
#  'answ',
#  'for-profit',
#  'dysfunct',
#  'automatic',
#  'customisable',
#  'brunel',
#  'msgee',
#  'neuropsychologist',
#  'upskill',
#  'opinion',
#  "'credits",
#  'specialist',
#  'protocol',
#  'empirical',
#  'assets',
#  'past',
#  'integr',
#  'secure',
#  'anthropologist',
#  'asian',
#  'infect',
#  'correspond',
#  'fletcher',
#  'electrochemistry',
#  'practitioners',
#  'umbrella',
#  'career-ori',
#  'assessors',
#  'cryptocurrency',
#  'miner',
#  '11-week',
#  'interrel',
#  'put',
#  'mid-november',
#  'preclin',
#  'trove',
#  'nutrient',
#  'systems-think',
#  'caofdi',
#  'thos',
#  'ecological',
#  'roadmap',
#  'microscal',
#  'worlds',
#  'centuries',
#  'recognised',
#  'post-registr',
#  '83.9k',
#  'hierarchy',
#  'health',
#  'li',
#  'leverag',
#  'food-safety',
#  'industry-recogn',
#  'ethnography',
#  'optimum',
#  'adulteration',
#  'stellenbosch',
#  'united',
#  'ucw',
#  'toxicology',
#  'legal',
#  'leath',
#  'cscs',
#  'mib',
#  'particulari',
#  'byzantin',
#  'chip-mak',
#  'perception',
#  'approval',
#  'lifelin',
#  'view/download',
#  'esdc',
#  'eirsat-1',
#  'limitations',
#  '97',
#  'masters',
#  'admission',
#  'offlin',
#  '\ufeffideal',
#  'leading/act',
#  'categoris',
#  'harbour.space',
#  'physiolog',
#  'client',
#  'traine',
#  'veterinarians',
#  'nhs',
#  'lisbon',
#  'planes',
#  'geoscientist',
#  'sentencing',
#  'kenya',
#  'sql',
#  'quarter',
#  'nine-month',
#  'skill-focus',
#  'functions',
#  '2036',
#  'weblearn',
#  'veränderungen',
#  'skillset',
#  'newest',
#  'dumping',
#  'prmia',
#  'warsaw',
#  'webinar',
#  'palace',
#  'wais',
#  'shot',
#  'captiv',
#  'wilmington',
#  'admiss',
#  'virginia',
#  'today',
#  'piri',
#  'masses',
#  'high-calibr',
#  'prosperity',
#  'peoples',
#  'foreseen',
#  'cruis',
#  'provision',
#  'crit',
#  'casual',
#  'derivatives',
#  'latter',
#  'scholarships',
#  'gen',
#  'linkag',
#  'datasets',
#  'santiago',
#  'poverti',
#  'crédit',
#  'professionals',
#  'fallibility',
#  'accelerating',
#  'press',
#  'bible',
#  'lshtm',
#  'terrestrial',
#  'endors',
#  'efficient',
#  'triple-crown',
#  'valuable',
#  'formally',
#  'crane',
#  'entities',
#  'subjects',
#  'nyit-old',
#  'ecommerc',
#  'brands',
#  'values',
#  'legisl',
#  'digitalis',
#  'discipline-transcend',
#  'multi-drug-resist',
#  'charg',
#  'computation',
#  'estimation',
#  'genocid',
#  'administrators',
#  'assimil',
#  'influenti',
#  'started',
#  'environmentally',
#  'uwl',
#  'singl',
#  'satisfact',
#  'dietitians',
#  'decemb',
#  'conversion',
#  'illeg',
#  'fieldtrip',
#  'once-in-a-lifetim',
#  'multi-lingu',
#  'efficiently',
#  'point-of-car',
#  'leave',
#  'duties',
#  'physiotherapi',
#  'interced',
#  'campaign',
#  'respond',
#  'multicor',
#  'biomanufacturing',
#  'cornwall',
#  'chatbots',
#  'impatiens',
#  'capacity',
#  'lab',
#  'madrid',
#  'statista',
#  'progamm',
#  'nanoengin',
#  'leading-edg',
#  'herauskommen',
#  '/or',
#  'e-procur',
#  'volatile',
#  'fantast',
#  'students',
#  'skeleton',
#  'rowett',
#  'analysed',
#  'customiz',
#  'ev',
#  'signed',
#  'stabl',
#  'hr-relat',
#  'universities',
#  'outlook',
#  'drones',
#  'lake',
#  'identifi',
#  'connoisseur',
#  'mscres',
#  'literature-bas',
#  'specif',
#  'mscegm',
#  'easy-to-us',
#  'exploit',
#  '1980s',
#  'ist',
#  'workers',
#  'part-time/onlin',
#  'specialti',
#  'management—but',
#  '14',
#  'entrepreneurs',
#  'mind-set',
#  'pace',
#  'philippin',
#  'bud',
#  'manner—th',
#  'einen',
#  'credibl',
#  'truli',
#  'mla',
#  'tampere',
#  'photosynthet',
#  'landmark',
#  'reconstruction',
#  'imag',
#  'cim-approv',
#  'self-harm',
#  'lund',
#  'thermofluid',
#  '//www.wiso.uni-hamburg.de/msc-econ',
#  'silica',
#  'institutional',
#  'held',
#  'deficit',
#  'hei',
#  'child',
#  'shetland',
#  'lasp',
#  'peak',
#  'platform',
#  'grang',
#  'einig',
#  'entir',
#  'mph',
#  'perspectives',
#  'ami',
#  'aviat',
#  'majesty',
#  'licens',
#  'blended',
#  'glasshouse',
#  'adaptation',
#  'socio-behavioural',
#  'categori',
#  'programm',
#  'advanc',
#  'horticultur',
#  'eastern',
#  'efficiency',
#  'photoshop',
#  'anthropolog',
#  'ag',
#  'phy-gital',
#  'team-working',
#  'manikin',
#  'high-volum',
#  'rescourc',
#  'spent',
#  'imageri',
#  'bcs',
#  'shipping',
#  'sponsorship',
#  'bioenergy',
#  'eyewit',
#  'chemicals',
#  '£48',
#  'maths',
#  'bmes',
#  'agenda',
#  '\ufeffdo',
#  'peace',
#  'variou',
#  'initiatives',
#  'loughborough',
#  'equis-',
#  'optoelectron',
#  'descriptive',
#  'quantifi',
#  'excurs',
#  'seminar',
#  'civiltà',
#  'skies',
#  'emphasis',
#  'merchandising',
#  'time-constrain',
#  'electrocutions',
#  'enorm',
#  'horses',
#  'high-qu',
#  'eith',
#  'first-hand',
#  'business/manag',
#  'embodi',
#  'doctorate',
#  'architect',
#  'beij',
#  'sonograph',
#  'alumni',
#  'post',
#  'family-centr',
#  'audience',
#  'defenc',
#  'pandemics',
#  'wide-spread',
#  'playing',
#  'practical-focus',
#  'step',
#  'amidst',
#  'gastroenterolog',
#  'reserve',
#  'laboratory-bas',
#  'topologies',
#  'salary',
#  'radiomics',
#  'vertebrates',
#  'simplifi',
#  'endocrinolog',
#  'pattern',
#  'cast',
#  'cohort',
#  'korea',
#  'leaders',
#  'museo',
#  'artefacts',
#  'arup',
#  'internationally-accredit',
#  'yes',
#  'algal',
#  'spreadsheet',
#  'equin',
#  'actions',
#  'doubl',
#  'cross-bord',
#  'harbour.spac',
#  'industry-accredit',
#  'adher',
#  '2021.',
#  'bases',
#  'biology',
#  'includes',
#  'underl',
#  'distil',
#  'nationally',
#  'open',
#  'tool-less',
#  'bscah',
#  'exclud',
#  'immunity',
#  'end-of-life',
#  'witnesses',
#  'management-engin',
#  'michael',
#  'every',
#  'psychology',
#  'empires',
#  '\ufeffprove',
#  'colombia',
#  'big',
#  'valid',
#  'cologne',
#  'datastream',
#  'sake',
#  'commission',
#  'msc/pg',
#  'florist',
#  'occurrences',
#  'space-bas',
#  'resource-limit',
#  'berkeley',
#  'olbia',
#  'agricultur',
#  'alon',
#  'licensing',
#  'intermaths',
#  'speech',
#  'day-to-day',
#  'material',
#  'part',
#  'hsbc',
#  'extern',
#  'paramedic',
#  'chromium',
#  'incom',
#  'indisput',
#  'enhanced',
#  'red',
#  'coastal',
#  'session',
#  'alert',
#  'institut',
#  'propel',
#  'nestl',
#  'bioscienc',
#  'pentagon',
#  'guowenyan',
#  'competencies',
#  'mental',
#  'psychodynam',
#  'physiotherapist',
#  'amazon',
#  'surg',
#  'multi-dimension',
#  'scarciti',
#  'spheres',
#  'internationalis',
#  'let',
#  'messages',
#  'appear',
#  'food-rel',
#  'twins',
#  'format',
#  'addresses',
#  'wsa',
#  'duti',
#  'intermath',
#  'mechan',
#  'commissioners',
#  'privaci',
#  'incorporated',
#  'reprogramming',
#  'dysfunctions',
#  'english',
#  'ma/msc',
#  'nanosci',
#  'high-pay',
#  'icraf',
#  'uk/eu',
#  'cmm',
#  'rankings',
#  'ifr',
#  'healthy',
#  'recovery',
#  'technology-enhanc',
#  'wholli',
#  'spoilage',
#  'maximis',
#  'programmers',
#  'ecotourism',
#  'consultancy/advisori',
#  'ethic',
#  'super',
#  'influenc',
#  'qicn',
#  'highly-skil',
#  'hybridis',
#  'rockstar',
#  '2050',
#  'film',
#  'drive',
#  'photographi',
#  'harsh',
#  'statist',
#  'teacher',
#  '3200',
#  'chemists',
#  'audits',
#  'border-cross',
#  'significant',
#  'processors',
#  'options',
#  'chemotherapeut',
#  'interacting',
#  'sub-areas',
#  'electronics',
#  'meetings',
#  'supervised',
#  'post-excav',
#  'organism',
#  '2023',
#  'pillar',
#  'fähigkeiten',
#  'congenital',
#  'analogue',
#  'microbiom',
#  'journalism',
#  'added',
#  'ga',
#  'empathet',
#  'champion',
#  'medicines',
#  '1400',
#  'multi-skil',
#  'bright',
#  'rhythm',
#  'factor',
#  'sovereignti',
#  'channel',
#  'sensorimotor',
#  '2025',
#  '1995',
#  "'hands-on",
#  'mandatori',
#  'basi',
#  'biologist',
#  'frontrunn',
#  'society',
#  'next-generation',
#  'neuropsychiatr',
#  'vulnerable',
#  'self-develop',
#  'reserves',
#  'january-intak',
#  'entertain',
#  'handle',
#  'activities',
#  'student-centr',
#  'articles',
#  'bachelor',
#  'ic',
#  'nowadays',
#  'fem',
#  'experimentally-deriv',
#  'publishing',
#  'audiovestibular',
#  'advice',
#  'triniti',
#  'choice',
#  'given',
#  'infrastructur',
#  'city',
#  'ghrm',
#  "'neglected",
#  'hpe',
#  'recessions',
#  'systemat',
#  'dent',
#  'emancipatori',
#  'game',
#  'gphc',
#  '–relat',
#  'ai-control',
#  'instruction',
#  'tuberculosis',
#  'it-rel',
#  'non-convent',
#  'frameworks.th',
#  'retailing',
#  'researching',
#  'progress',
#  'futures-orient',
#  'productive',
#  'pedagogies',
#  'majors',
#  'rein',
#  'multidimension',
#  'neoma',
#  'service-rel',
#  'embark',
#  'name',
#  'themes',
#  'payment',
#  'drought',
#  'whatev',
#  'superb',
#  'wollen',
#  'grant',
#  'esg',
#  'characterized',
#  'professionalism',
#  'geotechnology',
#  'audencia',
#  'masteri',
#  'victimisation',
#  'sick',
#  'social',
#  'stay',
#  'copyright',
#  'either',
#  'well-being',
#  'trace',
#  'columbia',
#  'twelve-month',
#  'frankfurt',
#  'soft-tissu',
#  'survivor',
#  'string',
#  'ii',
#  'chances',
#  'scarc',
#  'specul',
#  'bioimaging',
#  'july',
#  'scm',
#  'contexts',
#  'dip',
#  'accountants',
#  'drph',
#  'chos',
#  'msk',
#  '.',
#  '49,000',
#  'introduct',
#  'swarm',
#  'kent',
#  'convent',
#  'eth',
#  'divisions',
#  'next-gener',
#  'sedimentolog',
#  'run',
#  'negev',
#  'masters/postgradu',
#  'dhabi',
#  'samsung',
#  'nicosia',
#  'illness',
#  'enact',
#  'establishment',
#  'gamif',
#  'person',
#  'ihe',
#  '71',
#  '£13',
#  'disruptionen',
#  'trilemma',
#  'composites',
#  'sub-area',
#  'mutual',
#  'argu',
#  'ubisoft',
#  'macroeconomics',
#  'broadly',
#  'point-process',
#  'ite',
#  'monolingu',
#  'machineri',
#  'technologies',
#  'tunnel',
#  'naab-accredit',
#  'community',
#  'classif',
#  'rocket',
#  'compete',
#  'physics.\u200b',
#  'england',
#  'neuropharmacolog',
#  'biomedicine',
#  'magnet',
#  'compris',
#  'trinity',
#  'confluenc',
#  'ibhc',
#  'keele',
#  'anatom',
#  'eye',
#  'ideologies',
#  'messag',
#  'toxic',
#  'inspired',
#  'pacemak',
#  'top-10',
#  'lively',
#  '8,000-word',
#  'transfer',
#  'cta',
#  "'industri",
#  'proport',
#  'intrapreneurs',
#  'w',
#  'chip',
#  'cyberthreats',
#  'profiteering',
#  'science/postgradu',
#  'forc',
#  'increases',
#  'furnitur',
#  'structuralist',
#  'chemical-bas',
#  'blood',
#  '8.3',
#  'rapidly-grow',
#  'volcanology',
#  'climate-friendli',
#  'haematolog',
#  'sever',
#  'conserv',
#  'activist',
#  'ports',
#  'wrought',
#  'microsystem',
#  'bio-industri',
#  'surfactants',
#  'developed',
#  'post-disast',
#  'easili',
#  'ccl',
#  '12.45pm',
#  ...}

# %% [markdown]
#  Assign unique ID to each term in the vocabulary

# %%
vocabulary_list = list(vocabulary)
vocabulary_dict = {word: index for index, word in enumerate(vocabulary_list)}
vocabulary_df=pd.DataFrame(list(vocabulary_dict.items()), columns=['Word', 'Id'])
print(vocabulary_df.head())
# Out:
#             Word  Id
# 0         status   0
# 1    strategical   1
# 2  multi-million   2
# 3            mdp   3
# 4   registration   4

# %% [markdown]
# save it

# %%
vocabulary_df.to_csv('/content/drive/MyDrive/HM3-ADM/HW3_ADM/vocabulary.csv', index=False, header=False)
#remove header to keep the name of the columns

# %%
# Store in a json llike a pandas dataframe
vocabulary_df.to_json('/content/drive/MyDrive/HM3-ADM/HW3_ADM/vocabulary.json', orient='records')

# %%
# Write the dictionary to the JSON file directly
with open('/content/drive/MyDrive/HM3-ADM/HW3_ADM/vocabulary.json', 'w') as jsonfile:
    json.dump(vocabulary_dict, jsonfile)

# %%
vocabulary_reverse = vocabulary_df.copy()
print(vocabulary_reverse.head())
# Out:
#             Word  Id
# 0         status   0
# 1    strategical   1
# 2  multi-million   2
# 3            mdp   3
# 4   registration   4

# %%
from tqdm import tqdm
tqdm.pandas()
vocabulary_reverse['reverse'] = vocabulary_reverse.Word.progress_apply(lambda item: list(df.loc[df.description.apply(lambda row: item in row)].index))
# Out:
# 100%|██████████| 12557/12557 [01:39<00:00, 125.67it/s]

# %%
print('million' in vocabulary_reverse['Word'].values)
# Out:
# True

# %%
vocabulary_reverse.head()
# Out:
#             Word  Id                                            reverse
# 0         status   0  [383, 487, 488, 492, 576, 613, 629, 700, 1008,...
# 1    strategical   1  [1575, 1804, 2009, 2279, 2886, 2985, 3236, 377...
# 2  multi-million   2                                  [503, 2023, 3877]
# 3            mdp   3                                             [1439]
# 4   registration   4  [56, 380, 407, 439, 601, 620, 626, 748, 857, 1...

# %% [markdown]
# #### creating a dictionary

# %%
inverted_index = vocabulary_reverse.set_index('Id')['reverse'].to_dict()
count = 0
for key, value in inverted_index.items():
    if count < 5:
        print(f"Key: {key}, Value: {value}")
        count += 1
    else:
        break
# Out:
# Key: 0, Value: [383, 487, 488, 492, 576, 613, 629, 700, 1008, 1505, 1693, 1813, 2142, 2157, 2193, 2322, 2376, 2430, 2443, 2465, 2635, 2648, 3060, 3061, 3077, 3238, 3315, 3946, 4604, 4978, 5042, 5074, 5115, 5206, 5248, 5258, 5266, 5267, 5271, 5272, 5274, 5317]
# Key: 1, Value: [1575, 1804, 2009, 2279, 2886, 2985, 3236, 3770, 4066, 4294, 4330, 4773, 4844, 5922]
# Key: 2, Value: [503, 2023, 3877]
# Key: 3, Value: [1439]
# Key: 4, Value: [56, 380, 407, 439, 601, 620, 626, 748, 857, 1113, 1338, 1413, 1466, 1468, 1471, 1475, 1479, 1827, 1985, 1992, 1993, 2113, 2597, 2656, 2723, 2774, 2993, 3003, 3060, 3070, 3077, 3195, 3445, 4205, 4829, 4999, 5144, 5293, 5316, 5358, 5359, 5360, 5363, 5386, 5582, 5590, 5647, 5968]

# %%
with open('/content/drive/MyDrive/HM3-ADM/HW3_ADM/inverted_index.json', 'w') as file:
    json.dump(inverted_index, file)

# %% [markdown]
# ##[2.1.2]

# %% [markdown]
# selecting only the rows we need to return as output

# %%
df_query = df[['courseName','universityName','description','url']].copy()
df_query.head()
# Out:
#                                           courseName          universityName  \
# 0                        Air Quality Solutions - MSc     University of Leeds
# 1                          Analytical Toxicology MSc   King’s College London
# 2    Applied Computer Science and Artificial Inte...  University of Bradford
# 3    Applied Economics (Banking and Financial Mar...      University of Bath
# 4                          Applied Linguistics - MSc   University of Glasgow
#
#                                          description  \
# 0  Up to 7 million people are estimated to die ev...
# 1  The Analytical Toxicology MSc is a unique stud...
# 2  Computer science is the foundation of many exc...
# 3  From political uncertainty to finance and recr...
# 4  This Masters focuses on how linguistic researc...
#
#                                                  url
# 0  https://www.findamasters.com/masters-degrees/c...
# 1  https://www.findamasters.com/masters-degrees/c...
# 2  https://www.findamasters.com/masters-degrees/c...
# 3  https://www.findamasters.com/masters-degrees/c...
# 4  https://www.findamasters.com/masters-degrees/c...

# %%
df_query.shape
# Out:
# (5979, 4)

# %% [markdown]
# writing a function which extract all documents were all words are met

# %%
def engine(query):
    """
    Given a query made up by multiple word it returns the documents were ALL the word are found
    """
    doc_set_indexes = []
    words_in_query = query.split()

    for word in words_in_query:
        # Stemming the word
        stemmed_word = stemmer.stem(word)

        # Check if the stemmed word exists in the 'Word' column after applying stemming
        if stemmed_word in vocabulary_reverse['Word'].apply(stemmer.stem).values:
            # Get the document set indexes for the stemmed word
            indexes_for_word = vocabulary_reverse[vocabulary_reverse['Word'].apply(lambda x: x == stemmed_word)]['reverse'].values

            # Flatten the lists in 'reverse' column
            flattened_indexes = [item for sublist in indexes_for_word for item in sublist]

            # Append the flattened document set indexes to the list
            doc_set_indexes.append(flattened_indexes)
           # print(doc_set_indexes)

        else:
            print(f"Stemmed word '{stemmed_word}' not found in vocabulary_reverse")

    # Find the intersection of all document sets
    selected_doc = list(set.intersection(*map(set, doc_set_indexes)))

    # Select rows using iloc
    selected_rows = df.iloc[selected_doc]

    return selected_rows

# %%
engine('advance knowledge')
# Out:
#                                              courseName  \
# 1                             Analytical Toxicology MSc
# 5                          Accounting and Finance - MSc
# 8                                        Addictions MSc
# 2056                  Engineering with Management - MSc
# 2069    Enhanced Radiotherapy and Oncology Practice ...
# ...                                                 ...
# 2034                         Engineering Management MSc
# 4083           M2 Research in Management and Innovation
# 2038                         Engineering Management MSc
# 2042     Engineering Management via Study Centres - MSc
# 4092                         MA/MSc - Design Innovation
#
#                    universityName  \
# 1           King’s College London
# 5             University of Leeds
# 8           King’s College London
# 2056        University of Bristol
# 2069  Sheffield Hallam University
# ...                           ...
# 2034         Middlesex University
# 4083       Université Côte d’Azur
# 2038      University of Greenwich
# 2042     University of Sunderland
# 4092       De Montfort University
#
#                                             facultyName isItFullTime  \
# 1                   Faculty of Life Sciences & Medicine    Full time
# 5                      Leeds University Business School    Full time
# 8     Institute of Psychiatry, Psychology and Neuros...    Full time
# 2056                             Faculty of Engineering    Full time
# 2069                               Postgraduate Courses    Part time
# ...                                                 ...          ...
# 2034                  Faculty of Science and Technology    Full time
# 4083                      UCA International MSc Program    Full time
# 2038                              School of Engineering    Full time
# 2042                              Faculty of Technology    Full time
# 4092                        Arts, Design and Humanities    Full time
#
#                                             description           startDate  \
# 1     The Analytical Toxicology MSc is a unique stud...          See Course
# 5     Businesses and governments rely on sound finan...           September
# 8     Join us for an online session for prospective ...           September
# 2056  The MSc in Engineering with Management is desi...           September
# 2069  Enhance your knowledge of specific radiotherap...  September, January
# ...                                                 ...                 ...
# 2034  The career of an engineering project manager i...             October
# 4083  Our modern industry structures, value chains a...           September
# 2038  Extend and develop your skills and build a car...  September, January
# 2042  This course will broaden the knowledge and exp...          See Course
# 4092  With a flexible curriculum to accommodate your...           September
#
#                                                    fees modality  \
# 1     Please see the university website for further ...      MSc
# 5     UK: £18,000 (Total) \nInternational: £34,750 (...      MSc
# 8     Please see the university website for further ...      MSc
# 2056  Please see the university website for further ...      MSc
# 2069  For part-time study the fee will be calculated...      MSc
# ...                                                 ...      ...
# 2034  UK students \nFull-time students: £10,500 \nPa...      MSc
# 4083  The tuition currently stands at €243 as well a...      MSc
# 2038  Please see the university website for further ...      MSc
# 2042  Please see the university website for further ...      MSc
# 4092  2022/23 Full-time tuition fees for UK students...   MSc MA
#
#                                   duration        city administration  \
# 1                      Full-time: One year      London      On Campus
# 5                         1 year full time       Leeds      On Campus
# 8                              One year FT      London      On Campus
# 2056                      1 year full-time     Bristol      On Campus
# 2069   3 years part time distance learning   Sheffield         Online
# ...                                    ...         ...            ...
# 2034   1 year full-time; 2 years part-time      London      On Campus
# 4083                               2 years        Nice      On Campus
# 2038  1 years full-time, 2 years part-time      London      On Campus
# 2042           See course dates on website  Sunderland      On Campus
# 4092                      1 year full time   Leicester      On Campus
#
#              country                                                url
# 1     United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 5     United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 8     United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 2056  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 2069  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# ...              ...                                                ...
# 2034  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 4083          France  https://www.findamasters.com/masters-degrees/c...
# 2038  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 2042  United Kingdom  https://www.findamasters.com/masters-degrees/c...
# 4092  United Kingdom  https://www.findamasters.com/masters-degrees/c...
#
# [428 rows x 13 columns]
